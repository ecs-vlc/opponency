# %% [markdown]
# # Spectral Opponency
#
# This notebook plots the distribution of spectrally opponent, non-opponent and unresponsive cells
# in different layers of our model as a function of bottleneck size. It corresponds to Figure 1 in the paper.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from statistics import load

frame = pd.read_pickle('logs/devalois-random.pd')
print(frame[:10])

plt.figure(figsize=(3,2.5))

opps = load.spectral(frame, 'spectrally opponent')
retina2 = opps[opps['layer'] == 'retina_relu2']
ventral0 = opps[opps['layer'] == 'ventral_relu0']
ventral1 = opps[opps['layer'] == 'ventral_relu1']

plt.errorbar(retina2['n_bn'], retina2['mean_rel_amount'], yerr=retina2['std_rel_amount'], label='Retina2', linestyle=':')
plt.errorbar(ventral0['n_bn'], ventral0['mean_rel_amount'], yerr=ventral0['std_rel_amount'], label='Ventral1', linestyle='--')
plt.errorbar(ventral1['n_bn'], ventral1['mean_rel_amount'], yerr=ventral1['std_rel_amount'], label='Ventral2', linestyle='-.')
x1,x2,y1,y2 = plt.axis()
plt.axis([x1,x2,y1,y2])

plt.xlabel('Bottleneck Size')
plt.ylabel('Percentage \nSpectrally Opponent')
plt.xlim(1, 32)
plt.ylim(0, 1)
# plt.savefig('figures/spectrally_opponent.eps', bbox_inches='tight')

plt.figure(figsize=(3,2.5))

opps = load.spectral(frame, 'spectrally non-opponent')
retina2 = opps[opps['layer'] == 'retina_relu2']
ventral0 = opps[opps['layer'] == 'ventral_relu0']
ventral1 = opps[opps['layer'] == 'ventral_relu1']

plt.errorbar(retina2['n_bn'], retina2['mean_rel_amount'], yerr=retina2['std_rel_amount'], label='Retina2', linestyle=':')
plt.errorbar(ventral0['n_bn'], ventral0['mean_rel_amount'], yerr=ventral0['std_rel_amount'], label='Ventral1', linestyle='--')
plt.errorbar(ventral1['n_bn'], ventral1['mean_rel_amount'], yerr=ventral1['std_rel_amount'], label='Ventral2', linestyle='-.')
plt.axis([x1,x2,y1,y2])

plt.xlabel('Bottleneck Size')
plt.ylabel('Percentage \nSpectrally Non-opponent')
plt.xlim(1, 32)
plt.ylim(0, 1)
# plt.savefig('figures/spectrally_nonopponent.eps', bbox_inches='tight')

plt.figure(figsize=(3,2.5))

opps = load.spectral(frame, 'spectrally unresponsive')
retina2 = opps[opps['layer'] == 'retina_relu2']
ventral0 = opps[opps['layer'] == 'ventral_relu0']
ventral1 = opps[opps['layer'] == 'ventral_relu1']

plt.errorbar(retina2['n_bn'], retina2['mean_rel_amount'], yerr=retina2['std_rel_amount'], label='Retina2', linestyle=':')
plt.errorbar(ventral0['n_bn'], ventral0['mean_rel_amount'], yerr=ventral0['std_rel_amount'], label='Ventral1', linestyle='--')
plt.errorbar(ventral1['n_bn'], ventral1['mean_rel_amount'], yerr=ventral1['std_rel_amount'], label='Ventral2', linestyle='-.')
plt.axis([x1,x2,y1,y2])

plt.legend()
plt.xlabel('Bottleneck Size')
plt.ylabel('Percentage \nSpectrally Unresponsive')
plt.xlim(1, 32)
plt.ylim(0, 1)
# plt.savefig('figures/spectrally_unresponsive.eps', bbox_inches='tight')
# Out:
#            layer  cell                    class  max_params       max  \
# 0   retina_relu2     0  spectrally unresponsive           0  0.000000
# 1   retina_relu2     1  spectrally non-opponent         130  0.280941
# 2  ventral_relu0     0  spectrally unresponsive           0  0.000000
# 3  ventral_relu0     1  spectrally non-opponent         130  0.028733
# 4  ventral_relu0     2  spectrally non-opponent         130  0.025289
# 5  ventral_relu0     3  spectrally unresponsive           0  0.000000
# 6  ventral_relu0     4  spectrally unresponsive           0  0.000000
# 7  ventral_relu0     5  spectrally unresponsive           0  0.000000
# 8  ventral_relu0     6  spectrally unresponsive           0  0.000000
# 9  ventral_relu0     7  spectrally unresponsive           0  0.000000
#
#    min_params  min  spontaneous_rate  n_bn  d_vvs  rep  n_ch
# 0           0  0.0               0.0     2      3    8     3
# 1         320  0.0               0.0     2      3    8     3
# 2           0  0.0               0.0     2      3    8     3
# 3         320  0.0               0.0     2      3    8     3
# 4         320  0.0               0.0     2      3    8     3
# 5           0  0.0               0.0     2      3    8     3
# 6           0  0.0               0.0     2      3    8     3
# 7           0  0.0               0.0     2      3    8     3
# 8           0  0.0               0.0     2      3    8     3
# 9           0  0.0               0.0     2      3    8     3
# (0, 1)
